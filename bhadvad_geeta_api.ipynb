# %%
import requests

url = "https://shreemad-bhagvad-geeta.p.rapidapi.com/shlokas/1/1"

headers = {
	"x-rapidapi-key": "ca48341675msh484f0137a581ddep1272afjsn4d43a32b2e66",
	"x-rapidapi-host": "shreemad-bhagvad-geeta.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'_id': '66991b5d09a15b8e594c3388', 'chapter': 1, 'verse': 1, 'sanskrit': 'धृतराष्ट्र उवाच | धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सवः | मामकाः पाण्डवाश्चैव किमकुर्वत सञ्जय ||1-1||', 'hindi': 'धृतराष्ट्र बोले: हे संजय! धर्मभूमि कुरुक्षेत्र में एकत्रित, युद्ध की इच्छा से युक्त मेरे और पाण्डु के पुत्रों ने क्या किया?', 'english': 'Dhritarashtra said: O Sanjay, what did my sons and the sons of Pandu do when they assembled on the sacred field of Kurukshetra, eager to fight?', 'createdAt': '2024-07-18T13:40:45.308Z', '__v': 0}

# %%
import json

# Save the JSON response to a file
with open("data.json", "w") as f:
    json.dump(data, f, indent=4)

print("✅ JSON file saved as 'data.json'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-454ced421fcd> in <cell line: 0>()
#       3 # Save the JSON response to a file
#       4 with open("data.json", "w") as f:
# ----> 5     json.dump(data, f, indent=4)
#       6
#       7 print("✅ JSON file saved as 'data.json'")
#
# NameError: name 'data' is not defined

# %%
from google.colab import files

files.download("data.json")

# %%
import requests

url = "https://shreemad-bhagvad-geeta.p.rapidapi.com/shlokas/1/1"

headers = {
	"x-rapidapi-key": "ca48341675msh484f0137a581ddep1272afjsn4d43a32b2e66",
	"x-rapidapi-host": "shreemad-bhagvad-geeta.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'_id': '66991b5d09a15b8e594c3388', 'chapter': 1, 'verse': 1, 'sanskrit': 'धृतराष्ट्र उवाच | धर्मक्षेत्रे कुरुक्षेत्रे समवेता युयुत्सवः | मामकाः पाण्डवाश्चैव किमकुर्वत सञ्जय ||1-1||', 'hindi': 'धृतराष्ट्र बोले: हे संजय! धर्मभूमि कुरुक्षेत्र में एकत्रित, युद्ध की इच्छा से युक्त मेरे और पाण्डु के पुत्रों ने क्या किया?', 'english': 'Dhritarashtra said: O Sanjay, what did my sons and the sons of Pandu do when they assembled on the sacred field of Kurukshetra, eager to fight?', 'createdAt': '2024-07-18T13:40:45.308Z', '__v': 0}

# %%
import requests

url = "https://bhagavad-gita3.p.rapidapi.com/v2/chapters/"

querystring = {"skip":"0","limit":"18"}

headers = {
	"x-rapidapi-key": "ca48341675msh484f0137a581ddep1272afjsn4d43a32b2e66",
	"x-rapidapi-host": "bhagavad-gita3.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'id': 1, 'name': 'अर्जुनविषादयोग', 'slug': 'chapter-1-arjuna-visada-yoga', 'name_transliterated': 'Arjun Viṣhād Yog', 'name_translated': 'Arjuna Visada Yoga', 'verses_count': 47, 'chapter_number': 1, 'name_meaning': "Arjuna's Dilemma", 'chapter_summary': 'The first chapter of the Bhagavad Gita - "Arjuna Vishada Yoga" introduces the setup, the setting, the characters and the circumstances that led to the epic battle of Mahabharata, fought between the Pandavas and the Kauravas. It outlines the reasons that led to the revelation of the of Bhagavad Gita.\nAs both armies stand ready for the battle, the mighty warrior Arjuna, on observing the warriors on both sides becomes increasingly sad and depressed due to the fear of losing his relatives and friends and the consequent sins attributed to killing his own relatives. So, he surrenders to Lord Krishna, seeking a solution. Thus, follows the wisdom of the Bhagavad Gita.', 'chapter_summary_hindi': 'भगवद गीता का पहला अध्याय अर्जुन विशाद योग 
# ...

# %%
import pandas as pd
print(type(response.json()))
# Out:
# <class 'list'>

# %%
df=pd.DataFrame(response.json())
df
# Out:
#     id                        name                                       slug  \
# 0    1              अर्जुनविषादयोग               chapter-1-arjuna-visada-yoga
# 1    2                   सांख्ययोग                     chapter-2-sankhya-yoga
# 2    3                     कर्मयोग                       chapter-3-karma-yoga
# 3    4         ज्ञानकर्मसंन्यासयोग         chapter-4-jnana-karma-sanyasa-yoga
# 4    5              कर्मसंन्यासयोग               chapter-5-karma-sanyasa-yoga
# 5    6                    ध्यानयोग                      chapter-6-dhyana-yoga
# 6    7             ज्ञानविज्ञानयोग               chapter-7-gyaan-vigyana-yoga
# 7    8              अक्षरब्रह्मयोग              chapter-8-akshara-brahma-yoga
# 8    9        राजविद्याराजगुह्ययोग                  chapter-9-raja-vidya-yoga
# 9   10                   विभूतियोग                   chapter-10-vibhooti-yoga
# 10  11            विश्वरूपदर्शनयोग       chapter-11-vishwaroopa-darshana-yoga
# ...

# %%
pd.DataFrame(response.json())[['name','chapter_summary']]
# Out:
#                           name  \
# 0               अर्जुनविषादयोग
# 1                    सांख्ययोग
# 2                      कर्मयोग
# 3          ज्ञानकर्मसंन्यासयोग
# 4               कर्मसंन्यासयोग
# 5                     ध्यानयोग
# 6              ज्ञानविज्ञानयोग
# 7               अक्षरब्रह्मयोग
# 8         राजविद्याराजगुह्ययोग
# 9                    विभूतियोग
# 10            विश्वरूपदर्शनयोग
# 11                    भक्तियोग
# 12  क्षेत्र-क्षेत्रज्ञविभागयोग
# 13             गुणत्रयविभागयोग
# 14               पुरुषोत्तमयोग
# 15       दैवासुरसम्पद्विभागयोग
# 16         श्रद्धात्रयविभागयोग
# 17             मोक्षसंन्यासयोग
#
#                                       chapter_summary
# 0   The first chapter of the Bhagavad Gita - "Arju...
# 1   The second chapter of the Bhagavad Gita is "Sa...
# 2   The third chapter of the Bhagavad Gita is "Kar...
# 3   The fourth chapter of the Bhagavad Gita is "Jn...
# 4   The fifth chapter of the Bhagavad Gita is "Kar...
# ...

# %%
df.shape
# Out:
# (18, 10)

# %%
df.to_csv('Bhagvad_Geeta.csv')
